# %% [markdown]
# <a href="https://colab.research.google.com/github/karlik120/ds-learning/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plik = "/data/processed/2024/experiment_42_v3.csv"

# %%
nazwa_pliku = plik.split("/")[4]

# %%
nazwa_pliku
# Out:
# 'experiment_42_v3.csv'

# %%
katalog = plik.split("/")[0:4]

# %%
katalog = "/".join(katalog[1:4])

# %%
nazwa_bez_rozszerzenia = nazwa_pliku.split(".")[0]

# %%
nazwa_bez_rozszerzenia
# Out:
# 'experiment_42_v3'

# %%
rozszerzenie = nazwa_pliku.split(".")[1]

# %%
rozszerzenie
# Out:
# 'csv'

# %%
katalog
# Out:
# 'data/processed/2024'

# %%
rok_z_katalogu = katalog.split("/")[2]

# %%
rok_z_katalogu
# Out:
# '2024'
