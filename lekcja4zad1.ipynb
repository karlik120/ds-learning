# %% [markdown]
# <a href="https://colab.research.google.com/github/karlik120/ds-learning/blob/main/lekcja4zad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperatury = [22.5, 23.0, 21.5, 24.0, 23.5, 22.0, 23.0]

# %%
temperatury[-1]
# Out:
# 23.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_656/2845205808.py in <cell line: 0>()
# ----> 1 print(temperatury[0,-1,2:5])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print(temperatury[2:5])
# Out:
# [21.5, 24.0, 23.5]

# %%
print(temperatury[0])
# Out:
# 22.5
